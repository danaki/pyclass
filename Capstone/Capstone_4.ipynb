# %% [markdown]
# # Capstone project
# ## Poker hands
#
# ![hands.gif](attachment:hands.gif)
#
# Write a function to check for poker combinations, given rules (see pic or check [Wikipedia article](https://en.wikipedia.org/wiki/List_of_poker_hands)).
#
# Hand is given in standard poker notation. Example: `3D JC 8S 4H 2C`
#
# Your solution must return a string representing winning combination:
#  * High Card
#  * Pair
#  * Two Pair
#  * Three of a Kind
#  * Straight
#  * Flush
#  * Full House
#  * Four of a Kind
#  * Straight Flush
#  * Royal Flush

# %%
def poker_hand(hand):
    # your code here
    return None

# %% [markdown]
# Tests:

# %%
assert poker_hand('3D JC 8S 4H 2C') == 'High Card'
assert poker_hand('AS TC 2H 3H 8D') == 'High Card'
assert poker_hand('2H 3D 7D 9S TS') == 'High Card'
assert poker_hand('TS QH 3D 5D 6D') == 'High Card'
assert poker_hand('AH AD 8C 4S 7H') == 'Pair'
assert poker_hand('2H 3H 5H 7D 2C') == 'Pair'
assert poker_hand('9S TC 2S 8C 8S') == 'Pair'
assert poker_hand('AC QH 3D 5D 3H') == 'Pair'
assert poker_hand('4C 4S 3C 3D QC') == 'Two Pair'
assert poker_hand('2H 3H 2D 3S AS') == 'Two Pair'
assert poker_hand('TS QS KD QD TC') == 'Two Pair'
assert poker_hand('8D 7H 7C 8C AC') == 'Two Pair'
assert poker_hand('7C 7D 7S KC 3D') == 'Three of a Kind'
assert poker_hand('AD AH 2D 3C AC') == 'Three of a Kind'
assert poker_hand('KH QS QC 8C QD') == 'Three of a Kind'
assert poker_hand('2D 3D 2H 2C 5S') == 'Three of a Kind'
assert poker_hand('9C 8D 7S 6D 5H') == 'Straight'
assert poker_hand('AS 2S 3D 4H 5C') == 'Straight'
assert poker_hand('TC JH QD KD AD') == 'Straight'
assert poker_hand('3C 5H 4D 7D 6C') == 'Straight'
assert poker_hand('4C JC 8C 2C 9C') == 'Flush'
assert poker_hand('2D 5D 7D QD KD') == 'Flush'
assert poker_hand('8H 6H 7H KH AH') == 'Flush'
assert poker_hand('TS AS 2S 5S 8S') == 'Flush'
assert poker_hand('TH TD TS 9C 9D') == 'Full House'
assert poker_hand('2D 2S 2C 3C 3H') == 'Full House'
assert poker_hand('AH 5C 5D 5S AS') == 'Full House'
assert poker_hand('JH JD JS JC 7D') == 'Four of a Kind'
assert poker_hand('KD KH KS 2S KC') == 'Four of a Kind'
assert poker_hand('2D 3H 3C 3S 3D') == 'Four of a Kind'
assert poker_hand('9H 9C AC 9S 9D') == 'Four of a Kind'
assert poker_hand('8C 7C 6C 5C 4C') == 'Straight Flush'
assert poker_hand('AD 2D 3D 4D 5D') == 'Straight Flush'
assert poker_hand('2S 3S 4S 5S 6S') == 'Straight Flush'
assert poker_hand('3H 4H 5H 6H 7H') == 'Straight Flush'
assert poker_hand('AD KD QD JD TD') == 'Royal Flush'
assert poker_hand('KC JC AC TC QC') == 'Royal Flush'
assert poker_hand('TH QH AH JH KH') == 'Royal Flush'
assert poker_hand('QS TS KS JS AS') == 'Royal Flush'

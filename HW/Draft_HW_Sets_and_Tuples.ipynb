# %% [markdown]
# # HW: Sets and Tuples
#
# ## Problem: Robotic car
#
# Robotic car can move in 8 directions:
# * north (n)
# * north-east (ne)
# * east (e)
# * south-east (se)
# * south (s)
# * south-west (sw)
# * west (w)
# * north-west (nw)
#
# Replay the program and print finishing coordinates. Robot starts at position `(0, 0)`.
#
# Example of a command: `('ne', 17)` means 17 steps north-east (= +1 step up and +1 step right).
#
# ```
# [('ne', 17), ('e', 7), ('w', 1), ('nw', 4), ('s', 6), ('e', 3), ('n', 13), ('nw', 11), ('ne', 20), ('se', 7), ('s', 7), ('e', 4)]
# ```
#
# ![robot.png](attachment:robot.png)

# %%
program = [
    ('ne', 17),
    ('e', 7),
    ('w', 1),
    ('nw', 4),
    ('s', 6),
    ('e', 3),
    ('n', 13),
    ('nw', 11),
    ('ne', 20),
    ('se', 7),
    ('s', 7),
    ('e', 4)
]

x, y = 0, 0

# your solution here

# %% [markdown]
# # HW: Numerics and Math <a class="tocSkip">
#
# The goal of this assignment is to learn using numerics and `math` module.
#
# Find solutions to **all** problems described below. But first, run this line:

# %%
import math

# %% [markdown]
# It imports `math` module we going to use a lot during this assignment.

# %% [markdown]
# ## Circumference of a Circle
#
# The distance around a rectangle or a square is as you might remember called **the perimeter**. The distance around a circle on the other hand is called **the circumference**.
#
# ![circle01.png](attachment:circle01.png)
#
#  * A line that is drawn straight through the midpoint of a circle and that has its end points on the circle border is called the diameter (d)
#  * Half of the diameter, or the distance from the midpoint to the circle border, is called the radius of the circle (r).
#  * The circumference of a circle is found using this formula: $C=2 \pi \cdot r$ or $C=\pi \cdot d$
#
# [Source](https://www.mathplanet.com/education/pre-algebra/more-about-equation-and-inequalities/calculating-the-circumference-of-a-circle)
#
# You might want to watch this video lecture: https://youtu.be/Sk7raoAqCp0
#
# **Task:** calculate the circumference of a circle given `r = 112`.

# %%
# value of pi can be found in...
math.pi

# your solution here
# Out:
# 3.141592653589793

# %% [markdown]
# ## Calculate the area
#
# Use Python as a calculator to calculate area of the given figure.
#
# ![trapeze.jpeg](attachment:trapeze.jpeg)

# %%
# your solution here

# %% [markdown]
# ## Pythagorean theorem
#
# ![Pythagorean-Theorem.jpeg](attachment:Pythagorean-Theorem.jpeg)
#
# Refresher video: https://www.youtube.com/watch?v=uthjpYKD7Ng
#
# Hint: read [math](https://docs.python.org/2/library/math.html) module documentation and look for a function that computes square root of a number.
#
# Given:
#   * a = 5
#   * b = 12
#
# **Task:** compute length of hypotenuse c

# %%
# your solution here

# %% [markdown]
# ## Round $\pi$
#
# Using functions:
#   * [math.ceil()](https://docs.python.org/2/library/math.html#math.ceil)
#   * [math.floor()](https://docs.python.org/2/library/math.html#math.floor)
#   * [round()](https://docs.python.org/2/library/functions.html#round)
#
# and coercing to `int`
#
# Round `math.pi` to:
#   * 4.0
#   * 3.0
#   * 3.14
#   * 3

# %%
math.pi

# your code here
# Out:
# 3

# %% [markdown]
# ## Compound Interest
#
# ![compound-interest-eighth-wonder-of-the-world.jpg](attachment:compound-interest-eighth-wonder-of-the-world.jpg)
#
# Read [this article](https://www.mathsisfun.com/money/compound-interest.html) (or find better) first and then compute how much is the loan worth (future value) given:
#   * Invested sum: $1000
#   * Interest rate: 10%
#   * Number of periods: 10

# %%
# your computations here
